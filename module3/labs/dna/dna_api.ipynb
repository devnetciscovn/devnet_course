# %% [markdown]
# CODE GENERATED BY POSTMAN

# %%
import requests

url = "https://sandboxdnac.cisco.com/dna/system/api/v1/auth/token"

payload={}
headers = {
  'Authorization': 'Basic ZGV2bmV0dXNlcjpDaXNjbzEyMyE='
}

response = requests.request("POST", url, headers=headers, verify=False)

print(response.text)

# %% [markdown]
# Get Token By Authorization String

# %%
import requests
from credentials import *

url = base_url + '/dna/system/api/v1/auth/token'

headers = {
    'Authorization': authy_string
}

response = requests.post(url, headers = headers, verify = False)

# %%
response.status_code

# %%
response.json()['Token']

# %% [markdown]
# Get token by username and password

# %%
import requests
from credentials import dna_username, dna_password, base_url

url = base_url + '/dna/system/api/v1/auth/token'

response = requests.post(url, auth = (dna_username, dna_password), verify = False)
response.status_code

# %%
response.json()['Token']

# %% [markdown]
# FUNCTION TO GET TOKEN

# %%
import requests
from credentials import *

def get_token(username = '', password = '', authy_string = ''):
    url = base_url + '/dna/system/api/v1/auth/token'
    
    # If using Authorization String
    if authy_string:
        headers = {
        'Authorization': authy_string
        }
        response = requests.post(url, headers = headers, verify = False)        
        if response.json()['Token']:
            return response.json()['Token']
    
    # if using username and password
    if username and password:
        response = requests.post(url, auth = (username, password), verify = False)
        if response.json()['Token']:
            return response.json()['Token']

# %% [markdown]
# LIST ALL DEVICES

# %%
token = get_token(dna_username, dna_password)

# %%
url = base_url + '/api/v1/network-device'
headers = {
    'x-auth-token': token
}
response = requests.get(url, headers=headers, verify=False)

# %%
print(response.json()["response"][0]['hostname'])
print(response.json()["response"][0]['managementIpAddress'])

# %%
print(devices[0]['hostname'])
print(devices[0]['managementIpAddress'])

# %%
devices[0]

# %%
devices = response.json()["response"]

for device in devices:
    print(device["hostname"], device["managementIpAddress"], \
        device['softwareVersion'], device['type'], device['serialNumber'], sep = '\t')

# %%
hostname = 'c3504.abc.inc'
managementIpAddress = '10.10.20.51'
softwareVersion = '17.3.3'
type = 'Cisco 3504 Wireless LAN Controller'
sn = 'FOL25040021'

# %%
output = f"hostname is {hostname}, type is {type}"
print(output)

# %%
output = "hostnmae is {}, type is {}".format(hostname, type)
print(output)

# %%
output = "hostname: {2} type: {1} serinal number: {0}".format(sn, type, hostname)
print(output)
# Out:
# hostname: spine1.abc.inc type: Cisco Catalyst 9300 Switch serinal number: FOL25040021

# %%
output = "{0:15} {1:15} {2:15} {3:40} {4:10}".\
    format(hostname, managementIpAddress, softwareVersion, type, sn)

print(output)

# %%
for device in devices:
    hostname = device['hostname']
    managementIpAddress = device['managementIpAddress']
    softwareVersion = device['softwareVersion']
    type = device['type']
    serialNumber = device['serialNumber']

    output = "{0:15} {1:15} {2:15} {3:40} {4:10}".\
    format(hostname, managementIpAddress, softwareVersion, type, serialNumber)

    print(output)
# Out:
# c3504.abc.inc   10.10.20.51     8.5.140.0       Cisco 3504 Wireless LAN Controller       FOL25040021
# leaf1.abc.inc   10.10.20.81     17.3.3          Cisco Catalyst 9300 Switch               FCW2220G09V
# leaf2.abc.inc   10.10.20.82     16.11.1c        Cisco Catalyst 9300 Switch               FCW2211G0MA
# spine1.abc.inc  10.10.20.80     16.11.1c        Cisco Catalyst 9300 Switch               FOC2135Z00T
